# %% [markdown]
# <a href="https://colab.research.google.com/github/Lanka-ai/fmml-projects-and-labs/blob/main/Copy_of_FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-09 14:05:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   211MB/s    in 0.3s
#
# 2022-06-09 14:06:00 (211 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36687   1310.4756v1  Applying pre- and inprocessing techniques to s...    cs
# 11505  1605.00391v2  Causal inference concerns the identification o...  stat
# 19990   1303.5744v1  This paper introduces conceptual relations tha...    cs
# 3282    1410.0095v1  This paper advocates a novel framework for seg...  stat
# 4247   1712.04008v2  Transfer Learning helps to build a system to r...    cs
# ...             ...                                                ...   ...
# 142    1711.03640v1  We study the performance of stochastically tra...  stat
# 34896   1308.6384v1  Motivated by a problem in the theory of random...    cs
# 40312  1803.07512v1  We study how autonomous robots can learn by th...    cs
# 5417    1210.0762v1  Even though clustering trajectory data attract...    cs
# 25622  1510.06915v1  This paper presents a method for 3D segmentati...    cs
#
#                                                    title  year  \
# 36687  Effectiveness of pre- and inprocessing for CDC...  2013
# 11505  Recovery of non-linear cause-effect relationsh...  2016
# 19990           Truth as Utility: A Conceptual Synthesis  2013
# 3282                  Riemannian Multi-Manifold Modeling  2014
# 4247   Investigating the Impact of Data Volume and Do...  2017
# ...                                                  ...   ...
# 142      Stochastic Deep Learning in Memristive Networks  2017
# 34896       Collecting Coupons with Random Initial Stake  2013
# 40312  Fusion of stereo and still monocular depth est...  2018
# 5417   Graph-Based Approaches to Clustering Network-C...  2012
# 25622  Semi-Automatic Segmentation of Autosomal Domin...  2015
#
#                                                 keywords
# 36687  [inprocessing, techniques, considerably, perfo...
# 11505  [inference, identification, relationships, var...
# 19990  [introduces, conceptual, relations, synthesize...
# 3282   [advocates, framework, segmenting, riemannian,...
# 4247   [recognize, knowledge, experience, commonality...
# ...                                                  ...
# 142    [performance, stochastically, implemented, mem...
# 34896  [motivated, randomized, heuristics, collector,...
# 40312  [autonomous, themselves, estimation, capabilit...
# 5417   [clustering, trajectory, attracted, considerab...
# 25622  [segmentation, autosomal, polycystic, insuffic...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36687    [inprocessing, techniques, considerably, perfo...
# 11505    [inference, identification, relationships, var...
# 19990    [introduces, conceptual, relations, synthesize...
# 3282     [advocates, framework, segmenting, riemannian,...
# 4247     [recognize, knowledge, experience, commonality...
#                                ...
# 22067    [variational, inference, underlies, iterative,...
# 4574     [classification, technique, appropriate, repre...
# 14465    [collocation, hypothesis, distinctions, differ...
# 24435    [retrieval, considered, difficult, representat...
# 4450     [convolutional, generation, restoration, gener...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8785 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48d12240-2379-4047-a7fd-ce6dbf0db2fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48d12240-2379-4047-a7fd-ce6dbf0db2fc")) {                    Plotly.newPlot(                        "48d12240-2379-4047-a7fd-ce6dbf0db2fc",                        [{"x":["combinatorial","simplification","considerably","execution","instances","necessary","additional","combinations","algorithms","efficiency","variables","effectiveness","performance","worthwhile","subsequent","investigate","desirable","techniques","identification","contribution","constitute","neuroimaging","relationships","applicability","relationship","electroencephalography","introduced","restrictive","meaningful","comparative","indicates","analysing","furthermore","algorithm","combination","recovering","assumption","inference","conventional","introduces","relations","extending","synthesis","constraints","preferences","desirability","conceptual","solutions","represent","representation","synthesize","dependent","ignorance","restrictions","operations","structures","similarity","alternative","preference","differential","previously","formulations","introduce","constraint","reasoning","utilitarian","interpreted","mechanisms","aggregation","demonstrates","riemannian","importantly","application","efficient","clustering","segmentation","framework","grassmannian","thoroughly","geodesics","established","deviations","complication","simplified","segmenting","advocates","computationally","important","synthetic","information","underlying","guarantees","exploiting","extensive","directional","sequences","dimensional","intrinsic","theoretical","validation","constructs","continues","developing","practical","investigated","equivalent","experiments","knowledge","investigation","technique","investigating","applications","extraction","beneficial","distribution","experience","recognize","conditioned","attributes","represented","assumptions","undirected","multivariate","graphical","specified","relational","projection","independencies","including","consistent","distributions","factorizations","molecules","fundamental","mathematical","literature","invariances","compactly","structure","essential","projections","extension","associated","functions","particular","infectious","independence","complicated","applicable","projected","certainty","guarantee","acceptable","determine","satisfiability","discussed","resolution","partition","popularity","determines","discovery","community","simultaneously","likelihood","naturally","increased","addresses","correlation","particularly","benchmark","compatibility","parameters","involving","accessibility","conversion","classification","classifiers","contributing","understandable","converted","intuitive","requirements","widespread","challenging","presented","handwritten","comparison","relatively","interpretation","statistical","discusses","discussion","effectively","computing","implementations","determination","philosophical","evidential","contributes","reference"],"y":[36,9,25,29,80,79,108,41,556,170,124,203,880,2,27,151,31,409,116,72,11,5,76,23,69,0,135,9,51,37,20,9,174,784,136,24,67,227,106,74,83,36,47,150,34,5,18,148,106,370,18,83,1,24,68,120,145,95,23,34,84,12,309,115,126,2,28,53,27,45,10,21,242,426,142,201,592,6,14,0,53,8,4,15,20,2,86,356,136,685,112,57,53,166,21,102,184,42,158,48,19,10,64,131,43,48,618,347,37,262,20,432,122,24,224,32,45,19,69,77,65,11,19,53,31,37,46,5,244,91,114,5,3,91,58,140,3,4,311,60,26,72,112,219,242,0,36,32,49,13,9,34,19,88,14,47,113,28,21,19,36,102,113,68,52,38,58,65,84,222,3,242,44,3,13,513,100,7,7,16,37,52,13,266,163,17,149,50,49,171,21,23,111,150,31,15,6,8,14,49],"type":"bar"},{"x":["combinatorial","simplification","considerably","execution","instanc ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8241666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Person</span> <span style=''>Re</span> <span style='background-color:rgba(0, 255, 0, 0.3488372093023255);'>Identification</span> <span style=''>with</span> <span style=''>Vision</span> <span style=''>and</span> <span style=''>Language</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>person</span> <span style=''>re</span> <span style='background-color:rgba(0, 255, 0, 0.3488372093023255);'>identification</span> <span style=''>using</span> <span style=''>images</span> <span style=''>and</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.8421052631578947);'>descriptions</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>joint</span> <span style=''>vision</span> <span style=''>and</span> <span style=''>language</span> <span style=''>model</span> <span style=''>based</span> <span style=''>on</span> <span style=''>CCA</span> <span style=''>and</span> <span style=''>CNN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>architectures</span> <span style=''>to</span> <span style=''>match</span> <span style=''>across</span> <span style=''>the</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.6585365853658536);'>modalities</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>to</span> <span style=''>enrich</span> <span style=''>visual</span> <span style=''>examples</span> <span style=''>for</span> <span style=''>which</span> <span style=''>there</span> <span style=''>are</span> <span style=''>no</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.8421052631578947);'>descriptions</span> <span style=''>We</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.9240506329113923);'>annotations</span> <span style=''>in</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.8421052631578947);'>descriptions</span> <span style=''>for</span> <span style=''>two</span> <span style=''>standard</span> <span style=''>Re</span> <span style=''>ID</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>benchmarks</span> <span style=''>namely</span> <span style=''>CUHK03</span> <span style=''>and</span> <span style=''>VIPeR</span> <span style=''>We</span> <span style=''>perform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>these</span> <span style=''>two</span> <span style=''>datasets</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>based</span> <span style=''>on</span> <span style=''>CNN</span> <span style=''>hand</span> <span style=''>crafted</span> <span style=''>features</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>LSTM</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>analysing</span> <span style=''>visual</span> <span style=''>and</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.5333333333333333);'>description</span> <span style=''>data</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>investigate</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>advantages</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>perspective</span> <span style=''>of</span> <span style=''>sampling</span> <span style=''>scores</span> <span style=''>for</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>a</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>from</span> <span style=''>noisy</span> <span style=''>samples</span> <span style=''>Existing</span> <span style=''>work</span> <span style=''>has</span> <span style=''>focused</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximating</span> <span style=''>the</span> <span style=''>least</span> <span style=''>squares</span> <span style=''>solution</span> <span style=''>by</span> <span style=''>using</span> <span style=''>leverage</span> <span style=''>based</span> <span style=''>scores</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>importance</span> <span style=''>sampling</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>However</span> <span style=''>no</span> <span style=''>finite</span> <span style=''>sample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>and</span> <span style=''>no</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computationally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>optimal</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>To</span> <span style=''>evaluate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>properties</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>which</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style=''>analysis</span> <span style=''>and</span> <span style=''>is</span> <span style=''>useful</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>mean</span> <span style=''>square</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>for</span> <span style=''>any</span> <span style=''>given</span> <span style=''>sampling</span> <span style=''>scores</span> <span style=''>Based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Dimensionally</span> <span style=''>Tight</span> <span style=''>Running</span> <span style=''>Time</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>Second</span> <span style=''>Order</span> <span style='background-color:rgba(255, 0, 0, 0.6);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.6);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(HMC)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>deployed</span> <span style=''>method</span> <span style=''>to</span> <span style=''>sample</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695654);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.34615384615384615);'>Statistics</span> <span style=''>and</span> <span style=''>Machine</span> <span style=''>learning</span> <span style=''>HMC</span> <span style=''>is</span> <span style=''>known</span> <span style=''>to</span> <span style=''>run</span> <span style=''>very</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>and</span> <span style=''>its</span> <span style=''>second</span> <span style=''>order</span> <span style=''>variant</span> <span style=''>was</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>conjectured</span> <span style=''>to</span> <span style=''>run</span> <span style=''>in</span> <span style=''>d14</span> <span style=''>steps</span> <span style=''>in</span> <span style=''>1988</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjecture</span> <span style=''>is</span> <span style=''>true</span> <span style=''>when</span> <span style=''>sampling</span> <span style=''>from</span> <span style=''>strongly</span> <span style=''>log</span> <span style=''>concave</span> <span style=''>target</span> <span style='background-color:rgba(255, 0, 0, 0.30487804878048785);'>distributions</span> <span style=''>that</span> <span style=''>satisfy</span> <span style=''>weak</span> <span style=''>third</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularity</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>input</span> <span style=''>data</span> <span style=''>This</span> <span style=''>improves</span> <span style=''>upon</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>result</span> <span style=''>that</span> <span style=''>shows</span> <span style=''>that</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>steps</span> <span style=''>of</span> <span style=''>the</span> <span style=''>second</span> <span style=''>order</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discretization</span> <span style=''>of</span> <span style=''>HMC</span> <span style=''>grows</span> <span style=''>like</span> <span style=''>d14</span> <span style=''>under</span> <span style=''>the</span> <span style=''>much</span> <span style=''>stronger</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Dawid</span> <span style=''>Skene</span> <br/><br/><span style=''>Many</span> <span style=''>real</span> <span style=''>world</span> <span style=''>problems</span> <span style=''>can</span> <span style=''>now</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>solved</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>A</span> <span style=''>major</span> <span style=''>roadblock</span> <span style=''>is</span> <span style=''>often</span> <span style=''>the</span> <span style=''>lack</span> <span style=''>of</span> <span style=''>an</span> <span style=''>adequate</span> <span style=''>quantity</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>for</span> <span style=''>training</span> <span style=''>A</span> <span style=''>possible</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>to</span> <span style=''>assign</span> <span style=''>the</span> <span style=''>task</span> <span style=''>of</span> <span style=''>labeling</span> <span style=''>data</span> <span style=''>to</span> <span style=''>a</span> <span style=''>crowd</span> <span style=''>and</span> <span style=''>then</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>true</span> <span style=''>label</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>methods</span> <span style=''>A</span> <span style=''>well</span> <span style=''>known</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>is</span> <span style=''>the</span> <span style=''>Dawid</span> <span style=''>Skene</span> <span style=''>(DS)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>simple</span> <span style=''>yet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>EM</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style=''>a</span> <span style=''>hard</span> <span style=''>version</span> <span style=''>of</span> <span style=''>DS</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>much</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>similar</span> <span style=''>accuracy</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregation</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>how</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>method</span> <span style=''>can</span> <span style=''>be</span> <span style=''>extended</span> <span style=''>to</span> <span style=''>settings</span> <span style=''>when</span> <span style=''>there</span> <span style=''>are</span> <span style=''>multipl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.12415510494485948)
# 	processing (0.10174315190323728)
# 	representation (0.13162575595873355)
# 	segmentation (0.07150480256136606)
# 	information (0.24368552116684453)
# 	architecture (0.09569548203486304)
# 	detection (0.12664532194948416)
# 	recognition (0.12451085023123444)
# 	different (0.26609747420846674)
# 	convolutional (0.13945215225898258)
#
# Some Statistics words are:
# 	variables (0.12669683257918551)
# 	stochastic (0.12870789341377575)
# 	theoretical (0.14731020613373555)
# 	statistical (0.159376571141277)
# 	estimation (0.16842634489693314)
# 	algorithm (0.3866264454499749)
# 	dimensional (0.17345399698340874)
# 	distribution (0.19306184012066366)
# 	inference (0.19658119658119658)
# 	regression (0.18099547511312217)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ec7dc370-8132-481a-944a-65fd82547791" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec7dc370-8132-481a-944a-65fd82547791")) {                    Plotly.newPlot(                        "ec7dc370-8132-481a-944a-65fd82547791",                        [{"x":["combinatorial","simplification","considerably","execution","instances","necessary","additional","combinations","algorithms","efficiency","variables","effectiveness","performance","worthwhile","subsequent","investigate","desirable","techniques","identification","contribution","constitute","neuroimaging","relationships","applicability","relationship","electroencephalography","introduced","restrictive","meaningful","comparative","indicates","analysing","furthermore","algorithm","combination","recovering","assumption","inference","conventional","introduces","relations","extending","synthesis","constraints","preferences","desirability","conceptual","solutions","represent","representation","synthesize","dependent","ignorance","restrictions","operations","structures","similarity","alternative","preference","differential","previously","formulations","introduce","constraint","reasoning","utilitarian","interpreted","mechanisms","aggregation","demonstrates","riemannian","importantly","application","efficient","clustering","segmentation","framework","grassmannian","thoroughly","geodesics","established","deviations","complication","simplified","segmenting","advocates","computationally","important","synthetic","information","underlying","guarantees","exploiting","extensive","directional","sequences","dimensional","intrinsic","theoretical","validation","constructs","continues","developing","practical","investigated","equivalent","experiments","knowledge","investigation","technique","investigating","applications","extraction","beneficial","distribution","experience","recognize","conditioned","attributes","represented","assumptions","undirected","multivariate","graphical","specified","relational","projection","independencies","including","consistent","distributions","factorizations","molecules","fundamental","mathematical","literature","invariances","compactly","structure","essential","projections","extension","associated","functions","particular","infectious","independence","complicated","applicable","projected","certainty","guarantee","acceptable","determine","satisfiability","discussed","resolution","partition","popularity","determines","discovery","community","simultaneously","likelihood","naturally","increased","addresses","correlation","particularly","benchmark","compatibility","parameters","involving","accessibility","conversion","classification","classifiers","contributing","understandable","converted","intuitive","requirements","widespread","challenging","presented","handwritten","comparison","relatively","interpretation","statistical","discusses","discussion","effectively","computing","implementations","determination","philosophical","evidential","contributes","reference","sensitivities","admissible","extracting","illustrate","analytical","probabilistic","sensitivity","derivative","parameter","resulting","deviation","moderately","reconstructed","methodology","collaborative","feasibility","navigation","guidelines","reconstruction","reconstructions","environment","environments","monocular","sentiment","artificial","implementation","establishing","components","sarcastic","influence","linguistic","challenges","extraordinary","contextual","identifying","benchmarking","benchmarks","intuition","interaction","communication","sensitive","capability","classifying","communicative","different","potential","comprehensive","alternatives","regression","perceptron","connection","encouraging","recognition", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	electroencephalography
# 	geodesics
# 	infectious
# 	integrals
# 	downweighting
# 	distributionally
# 	stagewise
# 	ferromagnetic
# 	interpolates
# 	parametrizations
# 	trilinear
# 	equitability
# 	optimizers
# 	uncovering
# 	percolation
# 	cheminformatics
# 	solvation
# 	composers
# 	radiological
# 	parallels
# Some words which never appear in Statistics papers:
# 	simplification
# 	desirability
# 	utilitarian
# 	continues
# 	satisfiability
# 	accessibility
# 	evidential
# 	sensitivities
# 	navigation
# 	monocular
# 	sarcastic
# 	extraordinary
# 	communicative
# 	undecidable
# 	reachability
# 	executions
# 	obstacles
# 	quantifiable
# 	correspondences
# 	quantifiers

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.061380682687892e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
